# %% [markdown]
# ## PREPROCESAMIENTO COMPLETO DEL DATASET LAPOP BOLIVIA 2023 POR PASOS

# %% [markdown]
# Pipeline completo

# %%
import sys; sys.path.append('../..')

from src.preprocessing.preprocessor import DataPreprocessor
from src.utils.constants import RAW_DATA_PATH, RESULTS_PATH

print("=" * 70)
print("TEST PREPROCESSOR - DATASET REAL")
print("=" * 70)

dataset_path = RAW_DATA_PATH
preprocessor = DataPreprocessor()

# Ejecutar pipeline completo
print(f"\nEjecutando pipeline...")
df_final = preprocessor.run_pipeline(str(dataset_path))

# Mostrar resultados
print(f"\n✓ Pipeline completado")
print(f"  Dimensiones: {df_final.shape}")
print(f"  Missings: {df_final.isnull().sum().sum()}")

print(f"\nPrimeras 5 filas:")
print(df_final.head())

# Generar reporte
output_path = f"{RESULTS_PATH}/preprocessing/reporte_real.json"
preprocessor.generate_report(str(output_path))
print(f"\n✓ Reporte guardado en: {output_path}")

print("\n" + "=" * 70)
# Out:
# ======================================================================
# TEST PREPROCESSOR - DATASET REAL
# ======================================================================
#
# Ejecutando pipeline...
# Cargando dataset desde: C:\electocluster\data\raw\lapop_bolivia_2023.dta
# ✓ Dataset cargado: 1706 registros × 208 variables
# ⚠ Variables no encontradas en el dataset: ['wealth_index', 'civic_index']
# ✓ Variables seleccionadas: 40/42
# Reemplazando códigos especiales de LAPOP por NaN...
# ✓ Códigos especiales reemplazados por NaN
#
# ======================================================================
# RESUMEN DEL DATASET CARGADO
# ======================================================================
# Dimensiones: 1706 registros × 40 variables
# Missings totales: 3596
#
# Missings por variable:
#   edre                5 (  0.3%)
#   q10inc            199 ( 11.7%)
#   etid              189 ( 11.1%)
#   boletidnew         54 (  3.2%)
#   boletidnewb       850 ( 49.8%)
#   ocupoit           740 ( 43.4%)
#   q1tc_r             58 (  3.4%)
#   q3cn               62 (  3.6%)
#   q5b                16 (  0.9%)
#   r3                 12 (  0.7%)
#   r4a                 7 (  0.4%)
#   r6                  8 (  0.5%)
#   r7                  6 (  0.4%)
#   r12                 6 (  0.4%)
#   r15                 8 (  0.5%)
#   r18n               11 (  0.6%)
#   r18                 8 (  0.5%)
#   r16                 9 (  0.5%)
#   r27                14 (  0.8%)
#   leng1              12 (  0.7%)
#   formal            737 ( 43.2%)
#   wf1                 6 (  0.4%)
#   bolcct1a            6 (  0.4%)
#   bolcct1b            5 (  0.3%)
#   bolcct1c           13 (  0.8%)
#   q12cn               4 (  0.2%)
#   q12bn              10 (  0.6%)
#   gi0n                8 (  0.5%)
#   smedia3n          454 ( 26.6%)
#   cp6                12 (  0.7%)
#   cp7                 9 (  0.5%)
#   cp8                 7 (  0.4%)
#   cp13               16 (  0.9%)
#   q10e               22 (  1.3%)
#   q11n                4 (  0.2%)
#   leng4               9 (  0.5%)
# ======================================================================
# Validando rangos de variables...
# ✓ Validación de rangos completada
# Imputando valores faltantes...
#   ✓ edre: 5 missings imputados con moda (4.0)
#   ✓ q10inc: 199 missings imputados con moda (1003.0)
#   ✓ etid: 189 missings imputados con moda (2.0)
#   ✓ boletidnew: 54 missings imputados con moda (1.0)
#   ✓ boletidnewb: 850 missings imputados con moda (1.0)
#   ✓ ocupoit: 740 missings imputados con moda (5.0)
#   ✓ q1tc_r: 58 missings imputados con moda (1.0)
#   ✓ q3cn: 62 missings imputados con moda (1.0)
#   ✓ q5b: 16 missings imputados con moda (1.0)
#   ✓ r3: 12 missings imputados con moda (1.0)
#   ✓ r4a: 7 missings imputados con moda (1.0)
#   ✓ r6: 8 missings imputados con moda (0.0)
#   ✓ r7: 6 missings imputados con moda (0.0)
#   ✓ r12: 6 missings imputados con moda (1.0)
#   ✓ r15: 8 missings imputados con moda (0.0)
#   ✓ r18n: 11 missings imputados con moda (0.0)
#   ✓ r18: 8 missings imputados con moda (1.0)
#   ✓ r16: 9 missings imputados con moda (1.0)
#   ✓ r27: 14 missings imputados con moda (0.0)
#   ✓ leng1: 12 missings imputados con moda (1001.0)
#   ✓ formal: 737 missings imputados con moda (0.0)
#   ✓ wf1: 6 missings imputados con moda (0.0)
#   ✓ bolcct1a: 6 missings imputados con moda (0.0)
#   ✓ bolcct1b: 5 missings imputados con moda (1.0)
#   ✓ bolcct1c: 13 missings imputados con moda (0.0)
#   ✓ q12cn: 4 missings imputados con mediana (4.0)
#   ✓ q12bn: 10 missings imputados con mediana (1.0)
#   ✓ gi0n: 8 missings imputados con moda (1.0)
#   ✓ smedia3n: 454 missings imputados con moda (2.0)
#   ✓ cp6: 12 missings imputados con moda (4.0)
#   ✓ cp7: 9 missings imputados con moda (4.0)
#   ✓ cp8: 7 missings imputados con moda (4.0)
#   ✓ cp13: 16 missings imputados con moda (4.0)
#   ✓ q10e: 22 missings imputados con moda (2.0)
#   ✓ q11n: 4 missings imputados con moda (1.0)
#   ✓ leng4: 9 missings imputados con moda (2.0)
# ✓ Imputación completada
# Detectando outliers con método 'iqr'...
#   ⚠ q12cn: 45 outliers detectados (2.6%)
#   ⚠ q12bn: 20 outliers detectados (1.2%)
#
# ============================================================
# FEATURE ENGINEERING: construcción de índices compuestos
# ============================================================
#
# [1/2] Índice de riqueza material (variables R):
#   ✓ wealth_index creado (10 variables R → 1 índice, rango [0, 10])
#
# [2/2] Índice de participación cívica (variables CP):
#   ✓ civic_index creado (4 variables CP → 1 índice, rango [4, 16], escala invertida: mayor = más participativo)
#
# ============================================================
# ✓ Feature engineering completado:
#   Índices creados:        2
#   Variables eliminadas:   14
#   Dimensiones finales:    (1706, 28)
# ============================================================
# Codificando variables categóricas con método 'ordinal'...
#   ✓ edre recodificado a rango [0, 6]
#   ✓ edre normalizado a [0,1]
#   ✓ q10inc recodificado a rango [0, 14]
#   ✓ q10inc normalizado a [0,1]
#   ✓ etid (nominal) codificado con LabelEncoder y normalizado
#   ✓ boletidnew (binario) validado como 0/1
#   ✓ boletidnewb (nominal) codificado con LabelEncoder y normalizado
#   ✓ estratopri (nominal) codificado con LabelEncoder y normalizado
#   ✓ ur (binario) validado como 0/1
#   ✓ ocupoit (nominal) codificado con LabelEncoder y normalizado
#   ✓ q1tc_r (nominal) codificado con LabelEncoder y normalizado
#   ✓ q3cn (nominal) codificado con LabelEncoder y normalizado
#   ✓ q5b recodificado a rango [0, 3]
#   ✓ q5b normalizado a [0,1]
#   ✓ leng1 (nominal) codificado con LabelEncoder y normalizado
#   ✓ formal (binario) validado como 0/1
#   ✓ wf1 (binario) validado como 0/1
#   ✓ bolcct1a (binario) validado como 0/1
#   ✓ bolcct1b (binario) validado como 0/1
#   ✓ bolcct1c (binario) validado como 0/1
#   ✓ estratosec recodificado a rango [0, 2]
#   ✓ estratosec normalizado a [0,1]
#   ✓ gi0n recodificado a rango [0, 4]
#   ✓ gi0n normalizado a [0,1]
#   ✓ smedia3n recodificado a rango [0, 4]
#   ✓ smedia3n normalizado a [0,1]
#   ✓ q10e recodificado a rango [0, 2]
#   ✓ q10e normalizado a [0,1]
#   ✓ q11n (nominal) codificado con LabelEncoder y normalizado
#   ✓ leng4 (nominal) codificado con LabelEncoder y normalizado
# ✓ Codificación completada (23 variables)
# Normalizando variables numéricas con método 'minmax'...
#   ✓ q2 normalizado
#   ✓ q12cn normalizado
#   ✓ q12bn normalizado
#   ✓ wealth_index normalizado
#   ✓ civic_index normalizado
# ✓ Normalización completada (5 variables)
#
# ✓ Dataset procesado guardado en: C:\electocluster\data\processed\lapop_bolivia_2023_processed.csv
#
# ✓ Pipeline completado
#   Dimensiones: (1706, 28)
#   Missings: 0
#
# Primeras 5 filas:
#        edre    q10inc  etid  boletidnew  boletidnewb  estratopri   ur  \
# 0  1.000000  0.000000   0.2         1.0     0.142857         0.0  1.0
# 1  0.166667  0.285714   0.2         0.0     0.000000         0.0  1.0
# 2  0.500000  0.571429   0.2         1.0     0.000000         0.0  1.0
# 3  0.833333  0.214286   0.2         1.0     0.000000         0.0  1.0
# 4  0.833333  0.142857   0.2         0.0     0.000000         0.0  0.0
#
#     ocupoit        q2  q1tc_r  ...  estratosec     q12cn  q12bn  gi0n  \
# 0  0.555556  0.485714     0.5  ...         0.0  0.000000    0.0   0.0
# 1  0.777778  0.528571     0.0  ...         0.0  0.250000    0.3   0.0
# 2  1.000000  0.185714     0.0  ...         1.0  0.375000    0.3   0.0
# 3  0.555556  0.000000     0.0  ...         0.0  0.333333    0.2   0.5
# 4  0.555556  0.014286     0.0  ...         1.0  0.083333    0.0   0.0
#
#    smedia3n  q10e  q11n  leng4  wealth_index  civic_index
# 0      0.00   0.5   0.0   0.25           0.6     0.416667
# 1      0.75   1.0   0.2   0.25           0.7     0.000000
# 2      0.75   1.0   0.4   0.50           0.6     0.416667
# 3      0.25   0.5   0.0   0.25           1.0     0.000000
# 4      0.00   0.0   0.0   0.00           0.7     0.583333
#
# [5 rows x 28 columns]
#
# ✓ Reporte guardado en: C:\electocluster\results/preprocessing/reporte_real.json
#
# ======================================================================
