# %% [markdown]
# ## PONDERACIÓN DE CARACTERÍSTICAS - INICIALIZACIÓN CON CONSTANTS

# %% [markdown]
# Genera el JSON de pesos real desde constants.py en la ruta por defecto

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root))

from src.weighting.weight_manager import WeightManager

print('=' * 60)
print('WEIGHT MANAGER - INICIALIZACIÓN REAL')
print('=' * 60)

# Ruta por defecto: schemas/feature_weights.json
wm = WeightManager()

print(f'\n  JSON generado en: {wm.weights_path_}')
print(f'  Total features: {len(wm.features_)}')

wm.print_summary()
# Out:
# ...
# WEIGHT MANAGER - INICIALIZACIÓN REAL
# ...
# Pesos cargados desde c:\electocluster\src\weighting\schemas\feature_weights.json, total de características: 42.
#
#   JSON generado en: c:\electocluster\src\weighting\schemas\feature_weights.json
#   Total features: 42
#
# ...
#   WeightManager — c:\electocluster\src\weighting\schemas\feature_weights.json
#   Features: 42
# ...
#   edre                 1.00  ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#   q10inc               1.00  ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#   etid                 0.75  ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#   boletidnew           0.70  ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#   boletidnewb          0.70  ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# ...
